# %%
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA

pca = PCA(n_components=2)
X_pca = pca.fit_transform(X_real_scaled)
centroides_pca = pca.transform(kmeans_eval.cluster_centers_)

plt.figure(figsize=(10, 6))
plt.scatter(X_pca[:, 0], X_pca[:, 1], c=labels_eval, cmap='viridis', alpha=0.6, label='Transacciones')
plt.scatter(centroides_pca[:, 0], centroides_pca[:, 1], s=250, c='red', marker='X', edgecolors='black', label='Centroides')
plt.xlabel('Componente Principal 1 (PC1)')
plt.ylabel('Componente Principal 2 (PC2)')
plt.title('Proyeccion Espacial de Clusteres (Volumen y Producto)')
plt.legend()
plt.grid(True, alpha=0.3)
plt.show()


# 2. Productos clave por industria
# Extraemos el peso de cada tipo de combustible en la decision del modelo
importancias = pd.Series(best_rf_model.feature_importances_, index=X_train.columns)

plt.figure(figsize=(10, 6))
# Mostramos los combustibles mas determinantes
importancias.nlargest(10).sort_values().plot(kind='barh', color='#0f172a', edgecolor='white')

plt.title('Top 10 Combustibles mas Determinantes para Clasificar Industrias', fontsize=14)
plt.xlabel('Nivel de Importancia Predictiva', fontsize=12)
plt.ylabel('Tipo de Combustible', fontsize=12)
plt.grid(axis='x', linestyle='--', alpha=0.7)
plt.tight_layout()
plt.show()
